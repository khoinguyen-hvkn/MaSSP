# %% [markdown]
# <a href="https://colab.research.google.com/github/khoinguyen-hvkn/MaSSP/blob/master/keras/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras import optimizers
import matplotlib
import matplotlib.pyplot as plt

# 1. create pseudo data y = 2*x0 + 3*x1 + 4
X = np.random.rand(1000, 1)
y = 4 + 3 * X + .2*np.random.randn(1000, 1)

# 2. Build model 
model = Sequential([Dense(1, input_shape = (1,), activation='linear')])

# 3. gradient descent optimizer and loss function 
sgd = optimizers.SGD(lr=0.1)
model.compile(loss='mse', optimizer=sgd)

# 4. Train the model 
model.fit(X, y, epochs=100, batch_size=2)
# Out:
# Epoch 1/100
# 1000/1000 [==============================] - 1s 964us/step - loss: 0.1541
# Epoch 2/100
# 1000/1000 [==============================] - 0s 431us/step - loss: 0.0420
# Epoch 3/100
# 1000/1000 [==============================] - 0s 453us/step - loss: 0.0415
# Epoch 4/100
# 1000/1000 [==============================] - 0s 434us/step - loss: 0.0412
# Epoch 5/100
# 1000/1000 [==============================] - 0s 428us/step - loss: 0.0417
# Epoch 6/100
# 1000/1000 [==============================] - 0s 431us/step - loss: 0.0428
# Epoch 7/100
# 1000/1000 [==============================] - 0s 428us/step - loss: 0.0415
# Epoch 8/100
# 1000/1000 [==============================] - 0s 423us/step - loss: 0.0420
# Epoch 9/100
# 1000/1000 [==============================] - 0s 423us/step - loss: 0.0418
# Epoch 10/100
# 1000/1000 [==============================] - 0s 424us/step - loss: 0.0422
# Epoch 11/100
# 1000/1000 [==============================] - 0s 426us/step - loss: 0.0423
# ...

# %%
w=model.get_weights()
print(w[0][0])
print(w[1][0])
x0 = np.linspace(0, 1, 2, endpoint=True)
y0 = w[0][0]+w[1][0]*x0
# Draw the fitting line 
plt.plot(X.T, y.T, 'b.')     # data 
plt.plot(x0, y0, 'y', linewidth = 2)   # the fitting line
plt.axis([0, 1, 0, 10])
plt.show()
# Out:
# [3.0488784]
# 4.0534654
